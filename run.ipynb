# %%
# ! chmod +x run_general.sh
# ! ./run_general.sh

# ! chmod +x run_90_attacker.sh
# ! ./run_90_attacker.sh

# ! chmod +x run_lr_tuning.sh
# ! ./run_lr_tuning.sh

# ! chmod +x run_smart_attacker.sh
# ! ./run_smart_attacker.sh
